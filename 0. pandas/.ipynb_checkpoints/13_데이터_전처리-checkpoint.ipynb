# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import platform

if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'
elif platform.system() == 'Darwin':
    plt.rcParams['font.family'] = 'AppleGothic'
else:
    plt.rcParams['font.family'] = 'DejaVu Sans'

plt.rcParams['axes.unicode_minus'] = False
print('환경 설정 완료!')
# Out:
# 환경 설정 완료!

# %%
# [예제 1] 결측값 확인 (code7_1, code7_2)
import pandas as pd
import numpy as np

df = pd.read_csv('data/iris.csv')

# 인위적으로 결측값 주입
df.iloc[0, 1] = pd.NA
df.iloc[0, 2] = pd.NA
df.iloc[1, 2] = np.nan
df.iloc[2, 3] = None

print('컬럼별 결측값 수:')
print(df.isnull().sum())
print()
print('결측값이 있는 행:')
print(df.loc[df.isnull().sum(axis=1) > 0, :])
# Out:
# 컬럼별 결측값 수:
# Id               0
# SepalLengthCm    1
# SepalWidthCm     2
# PetalLengthCm    1
# PetalWidthCm     0
# Species          0
# dtype: int64
#
# 결측값이 있는 행:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            NaN           NaN            1.4           0.2  Iris-setosa
# 1   2            4.9           NaN            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            NaN           0.2  Iris-setosa

# %%
# [예제 2] 결측값 제거
import pandas as pd
import numpy as np

df = pd.read_csv('../data/iris.csv')
df.iloc[0, 1] = pd.NA
df.iloc[1, 2] = np.nan

# %%
# [예제 2] 데이터 정제 - 로우 삭제 및 인덱스 재설정
print('정제 전 행 수:', len(df))
df_clean = df.dropna().reset_index(drop=True)  # 결측값 행 제거 + 인덱스 재설정
print('정제 후 행 수:', len(df_clean))
print(df_clean.head())
# Out:
# 정제 전 행 수: 150
# 정제 후 행 수: 147
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   4            4.6           3.1            1.5           0.2  Iris-setosa
# 1   5            5.0           3.6            1.4           0.2  Iris-setosa
# 2   6            5.4           3.9            1.7           0.4  Iris-setosa
# 3   7            4.6           3.4            1.4           0.3  Iris-setosa
# 4   8            5.0           3.4            1.5           0.2  Iris-setosa

# %%
# [예제 3] 이상치 탐지 (code7_4)
import pandas as pd
import numpy as np
from scipy import stats

df = pd.read_csv('data/iris.csv')
sw = df['SepalWidthCm']

# Z-score 방법 (|z| > 2 기준)
z = np.abs(stats.zscore(sw))
outliers_z = sw[z > 2]
print('Z-score 이상치 (|z|>2):')
print(outliers_z.values)

# IQR 방법
Q1 = sw.quantile(0.25)
Q3 = sw.quantile(0.75)
IQR = Q3 - Q1
outliers_iqr = sw[(sw < Q1 - IQR*1.5) | (sw > Q3 + IQR*1.5)]
print(f'\nIQR 이상치 (Q1-1.5×IQR={Q1-1.5*IQR:.2f}, Q3+1.5×IQR={Q3+1.5*IQR:.2f}):')
print(outliers_iqr.values)

# 이상치 제거
clean = sw.loc[~sw.isin(outliers_iqr)]
print(f'\n원본 크기: {len(sw)} → 이상치 제거 후: {len(clean)}')
# Out:
# Z-score 이상치 (|z|>2):
# [4.  4.4 4.1 4.2 2. ]
#
# IQR 이상치 (Q1-1.5×IQR=2.05, Q3+1.5×IQR=4.05):
# [4.4 4.1 4.2 2. ]
#
# 원본 크기: 150 → 이상치 제거 후: 146

# %%
# [예제 4] 정렬 (sort_values), 순위 (rank) (code7_5, code7_6)
import pandas as pd

df = pd.read_csv('data/iris.csv')

# 정렬
print('SepalLengthCm 오름차순 상위 5행:')
print(df.sort_values('SepalLengthCm').head())

print('\nSpecies, Sepal_Width 복합 정렬 상위 5행:')
print(df.sort_values(['Species', 'SepalWidthCm']).head())

# 순위
print('\nPetalLengthCm 오름차순 순위 상위 5:')
print(df['PetalLengthCm'].rank().astype(int).head())
# Out:
# SepalLengthCm 오름차순 상위 5행:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 42  43            4.4           3.2            1.3           0.2  Iris-setosa
# 38  39            4.4           3.0            1.3           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa
#
# Species, Sepal_Width 복합 정렬 상위 5행:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
#
# PetalLengthCm 오름차순 순위 상위 5:
# 0    17
# 1    17
# 2     8
# 3    30
# 4    17
# Name: PetalLengthCm, dtype: int64

# %%
# [예제 6] Groupby
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# 단일 그룹 집계
print(f'품종 별 평균:')
df.groupby('Species').mean()
# Out:
# 품종 별 평균:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
# 다중 그룹 집계
df_mpg = pd.read_csv('data/mpg.csv')
df_mpg.head()
df_mpg.groupby(['cylinders', 'origin']).max()
# Out:
#                    mpg  displacement horsepower  weight  acceleration  \
# cylinders origin
# 3         3       23.7          80.0         97    2720          13.5
# 4         1       39.0         156.0          ?    3035          22.2
#           2       44.3         146.0          ?    3270          24.8
#           3       46.6         144.0         97    2711          21.0
# 5         2       36.4         183.0         77    3530          20.1
# 6         1       38.0         262.0          ?    3907          21.0
#           2       30.7         168.0         76    3820          19.6
#           3       32.7         168.0         97    2930          15.5
# 8         1       26.6         455.0         90    5140          22.2
#
#                   model year                     car name
# cylinders origin
# 3         3               80              mazda rx2 coupe
# 4         1               82        pontiac sunbird coupe
#           2               82             vw rabbit custom
#           3               82  toyouta corona mark ii (sw)
# 5         2               80           mercedes benz 300d
# 6         1               82           pontiac ventura sj
#           2               81                 volvo diesel
#           3               81               toyota mark ii
# 8         1               81          pontiac safari (sw)

# %%
# [예제 7] concat으로 DataFrame 결합 (code7_10)
import pandas as pd

df1 = pd.DataFrame([[169, 58, 1.0],
                    [172, 73, 1.2], 
                    [184, 82, 0.7]],
                   columns=['height', 'weight', 'eye'])
df2 = pd.DataFrame([[176, 71, 0.8, 'M'], 
                    [169, 62, 0.7, 'F']],
                   columns=['height', 'weight', 'eye', 'gender'])

# %%
# 행 방향 결합 (같은 컬럼 구조)
df12 = pd.concat([df1, df2]).reset_index(drop=True)
print('행 방향 concat 결과:')
df12
# Out:
# 행 방향 concat 결과:
#    height  weight  eye gender
# 0     169      58  1.0    NaN
# 1     172      73  1.2    NaN
# 2     184      82  0.7    NaN
# 3     176      71  0.8      M
# 4     169      62  0.7      F

# %%
# [예제 8] merge로 JOIN (code7_11)
import pandas as pd

df1 = pd.DataFrame([['a', 90], ['b', 80], ['c', 40]], columns=['name', 'kor'])
df2 = pd.DataFrame([['a', 75], ['b', 60], ['d', 90]], columns=['name', 'math'])

print('inner join (공통 이름만):')
print(df1.merge(df2, on='name'))

print('\nleft join (df1 기준 전체):')
print(df1.merge(df2, how='left', on='name'))

print('\nouter join (전체 포함):')
print(df1.merge(df2, how='outer', on='name'))
# Out:
# inner join (공통 이름만):
#   name  kor  math
# 0    a   90    75
# 1    b   80    60
#
# left join (df1 기준 전체):
#   name  kor  math
# 0    a   90  75.0
# 1    b   80  60.0
# 2    c   40   NaN
#
# outer join (전체 포함):
#   name   kor  math
# 0    a  90.0  75.0
# 1    b  80.0  60.0
# 2    c  40.0   NaN
# 3    d   NaN  90.0
