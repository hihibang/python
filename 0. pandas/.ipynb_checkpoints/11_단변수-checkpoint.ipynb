# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import platform
import pandas as pd

if platform.system() == 'Windows':
    matplotlib.rc('font', family='Malgun Gothic')
elif platform.system() == 'Darwin':
    matplotlib.rc('font', family='AppleGothic')
else:
    matplotlib.rc('font', family='DejaVu Sans')

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.dpi'] = 100

print('NumPy 버전:', np.__version__)
print('환경 설정 완료')
# Out:
# NumPy 버전: 2.3.5
# 환경 설정 완료

# %% [markdown]
# ### 1. 범주형 데이터

# %%
season = pd.Series(['봄','여름','가을','겨울','여름','겨울','봄','가을','겨울','여름','봄','여름','여름','겨울','겨울','겨울'])
# 도수분표 확인
season.value_counts()
# Out:
# 겨울    6
# 여름    5
# 봄     3
# 가을    2
# Name: count, dtype: int64

# %%
# 비율 계산 (favorite.value_counts() / favorite.size).round(2)
ratio = (season.value_counts()/ season.size).round(2)
ratio = ratio
ratio
# Out:
# 겨울    0.38
# 여름    0.31
# 봄     0.19
# 가을    0.12
# Name: count, dtype: float64

# %%
# 시각화 막대 그래프
import matplotlib.pyplot as plt

# 막대그래프
ratio.plot.bar(xlabel='계절', ylabel='빈도', rot=0,
             title='Favorite Season - Bar', color='steelblue')

plt.show() 

#원그래프
ratio.plot.pie(xlabel='계절', ylabel='빈도', rot=0,
             title='Favorite Season - Bar', color='steelblue')

plt.show()

# %% [markdown]
# ### 2. 수치형 데이터

# %%
from scipy import stats

# 정상 몸무게 데이터
weight1 = pd.Series([60, 62, 64, 65, 68, 69])

# 이상치(120kg) 한 명 추가
weight2 = pd.Series([60, 62, 64, 65, 68, 69, 120])

# %%
print(f'weight1의 평균 : {weight1.mean().round(2)}')
print(f'weight2의 평균 : {weight2.mean().round(2)}')

print(f'weight1의 평균 : {weight1.median()}')
print(f'weight2의 평균 : {weight2.median()}')

print(f'절사평균(20%) : {stats.trim_mean(weight2, 0.2):.1f}')
# Out:
# weight1의 평균 : 64.67
# weight2의 평균 : 72.57
# weight1의 평균 : 64.5
# weight2의 평균 : 65.0
# 절사평균(20%) : 65.6

# %%
iris = pd.read_csv('data/iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris['PetalLengthCm'].plot(
    kind='hist',
    bins = 20
)
plt.show()

# %%
titanic = pd.read_csv('data/titanic/train.csv')

# %%
titanic['Age'].plot(
    kind='hist',
    bins = 10
)
plt.show()

# %%
em_dict = {
    'S':0,
    'C':1,
    'E':2
}
titanic['Embarked_Number'] = titanic['Embarked'].map(em_dict)
titanic['Embarked_Number']
# Out:
# 0      0.0
# 1      1.0
# 2      0.0
# 3      0.0
# 4      0.0
#       ...
# 886    0.0
# 887    0.0
# 888    0.0
# 889    1.0
# 890    NaN
# Name: Embarked_Number, Length: 891, dtype: float64

# %%
titanic['Pclass'].plot(
    kind='hist',
    bins = 10
)
plt.show()

# %%
titanic.loc[0, 'Age'] = 1000

# %%
titanic['Age'].plot( # 이상치값으로 이상한 모양 발생 🧨
    kind='hist',
    bins = 10
)
plt.show()
