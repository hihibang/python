# %% [markdown]
# # 판다스 실습

# %%
import warnings
warnings.filterwarnings(action='ignore')

import pandas as pd
import numpy as np

# %%
### 1. 실습 데이터 준비
df = pd.read_csv('data/CARD_SUBWAY_MONTH_202605.csv', index_col=False) # 인덱스 만들어서 사용
df.head()
# Out:
#        사용일자  노선명   역명  승차총승객수  하차총승객수      등록일자
# 0  20260501  5호선   방이    5527    5357  20260504
# 1  20260501  5호선  둔촌동   10441    9979  20260504
# 2  20260501  5호선  상일동   10541    9932  20260504
# 3  20260501  5호선   고덕    7456    7257  20260504
# 4  20260501  5호선   명일    6377    6251  20260504

# %% [markdown]
# ## 2. 데이터 탐색

# %%
# 상위 5개의 데이터 탐색
df.head()
# Out:
#        사용일자  노선명   역명  승차총승객수  하차총승객수      등록일자
# 0  20260501  5호선   방이    5527    5357  20260504
# 1  20260501  5호선  둔촌동   10441    9979  20260504
# 2  20260501  5호선  상일동   10541    9932  20260504
# 3  20260501  5호선   고덕    7456    7257  20260504
# 4  20260501  5호선   명일    6377    6251  20260504

# %%
# 데이터프레임의 형태 확인
df.shape
# Out:
# (19131, 6)

# %%
# 하위 데이터 10개를 조회
df.tail(10)
# Out:
#            사용일자  노선명                역명  승차총승객수  하차총승객수      등록일자
# 19121  20260531  8호선                문정    7350    7431  20260603
# 19122  20260531  8호선                장지   10401    9980  20260603
# 19123  20260531  8호선                복정    5988    5340  20260603
# 19124  20260531  8호선                산성    3611    3915  20260603
# 19125  20260531  8호선  남한산성입구(성남법원.검찰청)    6905    6413  20260603
# 19126  20260531  8호선             단대오거리    6782    6559  20260603
# 19127  20260531  8호선                신흥    3732    3895  20260603
# 19128  20260531  8호선                수진    4223    3812  20260603
# 19129  20260531  8호선                모란    3406    2806  20260603
# 19130  20260531  8호선               남위례    4515    4530  20260603

# %%
# 데이터의 사분위수, 표준편차, 분산 등 통계지표 조회
df.describe()
# Out:
#                사용일자         승차총승객수         하차총승객수          등록일자
# count  1.913100e+04   19131.000000   19131.000000  1.913100e+04
# mean   2.026052e+07   11811.350740   11759.563640  2.026053e+07
# std    8.944833e+00   11836.994181   12011.261965  2.614125e+01
# min    2.026050e+07       1.000000       0.000000  2.026050e+07
# 25%    2.026051e+07    4125.000000    4022.000000  2.026051e+07
# 50%    2.026052e+07    8396.000000    8135.000000  2.026052e+07
# 75%    2.026052e+07   15701.500000   15507.500000  2.026053e+07
# max    2.026053e+07  101927.000000  115875.000000  2.026060e+07

# %%
# 데이터의 데이터 타입, 갯수 조회
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19131 entries, 0 to 19130
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용일자    19131 non-null  int64
#  1   노선명     19131 non-null  object
#  2   역명      19131 non-null  object
#  3   승차총승객수  19131 non-null  int64
#  4   하차총승객수  19131 non-null  int64
#  5   등록일자    19131 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 896.9+ KB

# %%
df['노선명'].nunique() # 27
df['노선명'].unique() # 27
# Out:
# array(['5호선', '4호선', '경의선', '3호선', '2호선', '1호선', '경인선', '경춘선', '공항철도 1호선',
#        '안산선', '과천선', '분당선', '서해선', '수인선', '신림선', '우이신설선', '일산선', '장항선',
#        '중앙선', '경원선', '경부선', '경강선', '9호선2~3단계', '9호선', '8호선', '7호선', '6호선'],
#       dtype=object)

# %%
df['역명'].nunique() # 27
df['역명'].unique() # 27
# Out:
# array(['방이', '둔촌동', '상일동', '고덕', '명일', '굽은다리(강동구민회관앞)', '길동', '강동',
#        '천호(풍납토성)', '광나루(장신대)', '아차산(어린이대공원후문)', '군자(능동)', '장한평', '답십리',
#        '마장', '왕십리(성동구청)', '행당', '신금호', '청구', '동대문역사문화공원(DDP)', '을지로4가',
#        '종로3가', '광화문(세종문화회관)', '서대문', '충정로(경기대입구)', '애오개', '공덕', '마포',
#        '여의나루', '여의도', '신길', '영등포시장', '영등포구청', '양평', '오목교(목동운동장앞)', '목동',
#        '신정(은행정)', '까치산', '화곡', '우장산', '발산', '마곡', '송정', '김포공항', '개화산',
#        '방화', '남태령', '사당', '총신대입구(이수)', '동작(현충원)', '이촌(국립중앙박물관)', '신용산',
#        '삼각지(전쟁기념관)', '숙대입구(갈월)', '서울역', '회현(남대문시장)', '명동', '충무로', '동대문',
#        '혜화', '한성대입구(삼선교)', '성신여대입구(돈암)', '길음', '미아사거리', '미아(서울사이버대학)',
#        '수유(강북구청)', '쌍문', '창동', '노원', '상계', '한국항공대', '불암산', '오금', '경찰병원',
#        '가락시장', '수서', '일원', '대청', '학여울', '대치', '도곡', '매봉', '양재(서초구청)',
#        '남부터미널(예술의전당)', '교대(법원.검찰청)', '고속터미널', '잠원', '신사', '압구정', '옥수',
#        '금호', '약수', '동대입구', '을지로3가', '안국', '경복궁(정부서울청사)', '독립문', '무악재',
# ...

# %%
# value_counts(): 몇번이나 반복(등장)하는가 확인
# 노선명 컬럼이 가지고 있는 데이터 분포 확인ㅁ
df['노선명'].value_counts()
# Out:
# 노선명
# 5호선         1736
# 2호선         1550
# 7호선         1302
# 경부선         1209
# 6호선         1193
# 분당선         1080
# 3호선         1053
# 경원선         1021
# 경의선          843
# 4호선          806
# 9호선          775
# 중앙선          651
# 경인선          620
# 경춘선          589
# 8호선          589
# 수인선          558
# 공항철도 1호선     434
# 우이신설선        403
# 9호선2~3단계     403
# 안산선          403
# 경강선          372
# 신림선          341
# 일산선          332
# 1호선          310
# 과천선          248
# 장항선          217
# 서해선           93
# Name: count, dtype: int64

# %% [markdown]
# ## 3. 정렬

# %%
df.sort_values(by = ['승차총승객수'], ascending=False).head(10)
# Out:
#            사용일자  노선명        역명  승차총승객수  하차총승객수      등록일자
# 118    20260501  2호선      홍대입구  101927  115875  20260504
# 8668   20260515  2호선  잠실(송파구청)  100436   98646  20260518
# 682    20260502  2호선      홍대입구  100394  111108  20260505
# 8674   20260515  2호선        강남   98157   96835  20260518
# 13541  20260522  1호선       서울역   97514   98036  20260525
# 4342   20260508  2호선  잠실(송파구청)   97402   98062  20260511
# 17330  20260529  2호선        강남   96864   95651  20260601
# 13571  20260522  2호선        강남   96755   95209  20260525
# 4336   20260508  2호선        강남   96539   95218  20260511
# 8643   20260515  1호선       서울역   96164   95369  20260518

# %%
df.sort_values(by = ['하차총승객수'], ascending=False)[0:10]
# Out:
#            사용일자  노선명        역명  승차총승객수  하차총승객수      등록일자
# 118    20260501  2호선      홍대입구  101927  115875  20260504
# 682    20260502  2호선      홍대입구  100394  111108  20260505
# 9497   20260516  2호선      홍대입구   93826  105809  20260519
# 14108  20260523  2호선      홍대입구   93902  105501  20260526
# 1898   20260504  2호선      홍대입구   91747  101530  20260507
# 18406  20260530  2호선      홍대입구   90426  101159  20260602
# 5217   20260509  2호선      홍대입구   88321   99335  20260512
# 8668   20260515  2호선  잠실(송파구청)  100436   98646  20260518
# 4342   20260508  2호선  잠실(송파구청)   97402   98062  20260511
# 13541  20260522  1호선       서울역   97514   98036  20260525

# %% [markdown]
# ## 4. 선택

# %%
# 사용일자 컬럼을 인덱스로 지정하여 df2 객체를 생성
df2 = df.set_index('사용일자')
df2
# Out:
#           노선명     역명  승차총승객수  하차총승객수      등록일자
# 사용일자
# 20260501  5호선     방이    5527    5357  20260504
# 20260501  5호선    둔촌동   10441    9979  20260504
# 20260501  5호선    상일동   10541    9932  20260504
# 20260501  5호선     고덕    7456    7257  20260504
# 20260501  5호선     명일    6377    6251  20260504
# ...       ...    ...     ...     ...       ...
# 20260531  8호선  단대오거리    6782    6559  20260603
# 20260531  8호선     신흥    3732    3895  20260603
# 20260531  8호선     수진    4223    3812  20260603
# 20260531  8호선     모란    3406    2806  20260603
# 20260531  8호선    남위례    4515    4530  20260603
#
# [19131 rows x 5 columns]

# %%
print(df.head(3))
print('-'*100)
print(df2.head(3))
# Out:
#        사용일자  노선명   역명  승차총승객수  하차총승객수      등록일자
# 0  20260501  5호선   방이    5527    5357  20260504
# 1  20260501  5호선  둔촌동   10441    9979  20260504
# 2  20260501  5호선  상일동   10541    9932  20260504
# ----------------------------------------------------------------------------------------------------
#           노선명   역명  승차총승객수  하차총승객수      등록일자
# 사용일자
# 20260501  5호선   방이    5527    5357  20260504
# 20260501  5호선  둔촌동   10441    9979  20260504
# 20260501  5호선  상일동   10541    9932  20260504

# %%
# 인덱스 검색 : loc/iloc
df2.iloc[1]
# Out:
# 노선명            5호선
# 역명             둔촌동
# 승차총승객수       10441
# 하차총승객수        9979
# 등록일자      20260504
# Name: 20260501, dtype: object

# %%
df2.loc[20260510]
# Out:
#           노선명    역명  승차총승객수  하차총승객수      등록일자
# 사용일자
# 20260510  7호선  태릉입구    6549    6519  20260513
# 20260510  5호선    신길    3197    3374  20260513
# 20260510  9호선  양천향교    5221    5473  20260513
# 20260510  9호선    가양   13415   13294  20260513
# 20260510  9호선    증미    3114    3300  20260513
# ...       ...   ...     ...     ...       ...
# 20260510  중앙선    양평    3155    2873  20260513
# 20260510  중앙선    원덕     479     373  20260513
# 20260510  중앙선    용문    4829    4286  20260513
# 20260510  중앙선    지평      63      70  20260513
# 20260510  2호선    방배    8554    8679  20260513
#
# [617 rows x 5 columns]

# %%
# 불린 인덱싱
df2['노선명']=='2호선'
# Out:
# 사용일자
# 20260501    False
# 20260501    False
# 20260501    False
# 20260501    False
# 20260501    False
#             ...
# 20260531    False
# 20260531    False
# 20260531    False
# 20260531    False
# 20260531    False
# Name: 노선명, Length: 19131, dtype: bool

# %%
# query
df2.query('노선명 == "2호선"')
# Out:
#           노선명         역명  승차총승객수  하차총승객수      등록일자
# 사용일자
# 20260501  2호선  용두(동대문구청)    1980    1746  20260504
# 20260501  2호선      신정네거리    7710    7364  20260504
# 20260501  2호선       양천구청    4845    4751  20260504
# 20260501  2호선        도림천     814     803  20260504
# 20260501  2호선        신설동    3984    3453  20260504
# ...       ...        ...     ...     ...       ...
# 20260531  2호선        신설동    3960    3664  20260603
# 20260531  2호선        도림천     910    1127  20260603
# 20260531  2호선       양천구청    3858    3948  20260603
# 20260531  2호선      신정네거리    6203    6115  20260603
# 20260531  2호선  용두(동대문구청)    1417    1393  20260603
#
# [1550 rows x 5 columns]

# %%
df.query('승차총승객수 >= 50000')['역명']
# Out:
# 86          고속터미널
# 118          홍대입구
# 134            강남
# 140      잠실(송파구청)
# 145            성수
#            ...
# 18583          용산
# 18856         서울역
# 18881    잠실(송파구청)
# 18904        홍대입구
# 18936       고속터미널
# Name: 역명, Length: 354, dtype: object

# %%
df[df['승차총승객수'] >=50000]['역명']
# Out:
# 86          고속터미널
# 118          홍대입구
# 134            강남
# 140      잠실(송파구청)
# 145            성수
#            ...
# 18583          용산
# 18856         서울역
# 18881    잠실(송파구청)
# 18904        홍대입구
# 18936       고속터미널
# Name: 역명, Length: 354, dtype: object

# %%
df[(df['승차총승객수'] >=50000) & (df['역명'] == '강남')]
# Out:
#            사용일자  노선명  역명  승차총승객수  하차총승객수      등록일자
#
#            사용일자  노선명  승차총승객수  하차총승객수
# 0      20260501  5호선    5527    5357
# 1      20260501  5호선   10441    9979
# 2      20260501  5호선   10541    9932
# 3      20260501  5호선    7456    7257
# 4      20260501  5호선    6377    6251
# ...         ...  ...     ...     ...
# 19126  20260531  8호선    6782    6559
# 19127  20260531  8호선    3732    3895
# 19128  20260531  8호선    4223    3812
# 19129  20260531  8호선    3406    2806
# 19130  20260531  8호선    4515    4530
#
# [19131 rows x 4 columns]

# %% [markdown]
# ## 6. 연산

# %%
df['승차총승객수_10'] = df['승차총승객수'] + 10
df
# Out:
#            사용일자  노선명     역명  승차총승객수  하차총승객수      등록일자  승차총승객수_10
# 0      20260501  5호선     방이    5527    5357  20260504       5537
# 1      20260501  5호선    둔촌동   10441    9979  20260504      10451
# 2      20260501  5호선    상일동   10541    9932  20260504      10551
# 3      20260501  5호선     고덕    7456    7257  20260504       7466
# 4      20260501  5호선     명일    6377    6251  20260504       6387
# ...         ...  ...    ...     ...     ...       ...        ...
# 19126  20260531  8호선  단대오거리    6782    6559  20260603       6792
# 19127  20260531  8호선     신흥    3732    3895  20260603       3742
# 19128  20260531  8호선     수진    4223    3812  20260603       4233
# 19129  20260531  8호선     모란    3406    2806  20260603       3416
# 19130  20260531  8호선    남위례    4515    4530  20260603       4525
#
# [19131 rows x 7 columns]

# %%
df['승하차총승객수'] = df['승차총승객수'] - df['하차총승객수']
df
# Out:
#            사용일자  노선명     역명  승차총승객수  하차총승객수      등록일자  승차총승객수_10  승하차총승객수
# 0      20260501  5호선     방이    5527    5357  20260504       5537      170
# 1      20260501  5호선    둔촌동   10441    9979  20260504      10451      462
# 2      20260501  5호선    상일동   10541    9932  20260504      10551      609
# 3      20260501  5호선     고덕    7456    7257  20260504       7466      199
# 4      20260501  5호선     명일    6377    6251  20260504       6387      126
# ...         ...  ...    ...     ...     ...       ...        ...      ...
# 19126  20260531  8호선  단대오거리    6782    6559  20260603       6792      223
# 19127  20260531  8호선     신흥    3732    3895  20260603       3742     -163
# 19128  20260531  8호선     수진    4223    3812  20260603       4233      411
# 19129  20260531  8호선     모란    3406    2806  20260603       3416      600
# 19130  20260531  8호선    남위례    4515    4530  20260603       4525      -15
#
# [19131 rows x 8 columns]

# %%
print(df['승하차총승객수'].mean())
print(df['승하차총승객수'].median())
print(df['승하차총승객수'].agg(['mean', 'median']))
# Out:
# 51.78709947206105
# 97.0
# mean      51.787099
# median    97.000000
# Name: 승하차총승객수, dtype: float64

# %%
df['승하차총승객수합계'] = df['승차총승객수'] + df['하차총승객수']
df
# Out:
#            사용일자  노선명     역명  승차총승객수  하차총승객수      등록일자  승차총승객수_10  승하차총승객수  \
# 0      20260501  5호선     방이    5527    5357  20260504       5537      170
# 1      20260501  5호선    둔촌동   10441    9979  20260504      10451      462
# 2      20260501  5호선    상일동   10541    9932  20260504      10551      609
# 3      20260501  5호선     고덕    7456    7257  20260504       7466      199
# 4      20260501  5호선     명일    6377    6251  20260504       6387      126
# ...         ...  ...    ...     ...     ...       ...        ...      ...
# 19126  20260531  8호선  단대오거리    6782    6559  20260603       6792      223
# 19127  20260531  8호선     신흥    3732    3895  20260603       3742     -163
# 19128  20260531  8호선     수진    4223    3812  20260603       4233      411
# 19129  20260531  8호선     모란    3406    2806  20260603       3416      600
# 19130  20260531  8호선    남위례    4515    4530  20260603       4525      -15
#
#        승하차총승객수합계
# 0          10884
# 1          20420
# 2          20473
# ...

# %%
print(df['승하차총승객수합계'].agg(['mean', 'median']))
# Out:
# mean      23570.91438
# median    16489.00000
# Name: 승하차총승객수합계, dtype: float64

# %%
# 인덱스 재생성 후 df2에 반영, 기존 인덱스 컬럼 유지
df2.reset_index(inplace = True)

# %%
df2.head()
# Out:
#        사용일자  노선명   역명  승차총승객수  하차총승객수      등록일자
# 0  20260501  5호선   방이    5527    5357  20260504
# 1  20260501  5호선  둔촌동   10441    9979  20260504
# 2  20260501  5호선  상일동   10541    9932  20260504
용일자  노선명         역명  승차총승객수  하차총승객수      등록일자  승하차총승객수
# 0  20260501  2호선  용두(동대문구청)    1980    1746  20260504      234
# 1  20260501  2호선      신정네거리    7710    7364  20260504      346
# 2  20260501  2호선       양천구청    4845    4751  20260504       94
# 3  20260501  2호선        도림천     814     803  20260504       11
# 4  20260501  2호선        신설동    3984    3453  20260504      531

# %% [markdown]
# ## 7. 샘플링

# %%
df_sample_10 = df.sample(n=10)
df_sample_10
# Out:
#            사용일자       노선명     역명  승차총승객수  하차총승객수      등록일자  승차총승객수_10  \
# 4710   20260508       경원선  동두천중앙    3661    3589  20260511       3671
# 14474  20260524       서해선   김포공항    2806    4045  20260527       2816
# 11869  20260520       경강선     판교    6946    6718  20260523       6956
# 6437   20260511       일산선    정발산    7694    7578  20260514       7704
# 17893  20260529       중앙선     지평      81      64  20260601         91
# 18560  20260531  9호선2~3단계  종합운동장    5737    4758  20260603       5747
# 8428   20260514       4호선    동대문   22817   23224  20260517      22827
# 14107  20260523       2호선     합정   35890   40339  20260526      35900
# 1200   20260502       경부선   성균관대   13088   12636  20260505      13098
# 16254  20260527     우이신설선     솔샘    6828    6581  20260530       6838
#
#        승하차총승객수  승하차총승객수합계
# 4710        72       7250
# 14474    -1239       6851
# 11869      228      13664
# 6437       116      15272
# 17893       17        145
# 18560      979      10495
# ...

# %% [markdown]
# ## 8. 그룹핑

# %%
print(df[['노선명', '사용일자', '사용일자']].value_counts)
# Out:
# <bound method DataFrame.value_counts of        노선명      사용일자      사용일자
# 0      5호선  20260501  20260501
# 1      5호선  20260501  20260501
# 2      5호선  20260501  20260501
# 3      5호선  20260501  20260501
# 4      5호선  20260501  20260501
# ...    ...       ...       ...
# 19126  8호선  20260531  20260531
# 19127  8호선  20260531  20260531
# 19128  8호선  20260531  20260531
# 19129  8호선  20260531  20260531
# 19130  8호선  20260531  20260531
#
# [19131 rows x 3 columns]>

# %%
df.groupby(['사용일자', '노선명']).count()
# Out:
#                 역명  승차총승객수  하차총승객수  등록일자  승차총승객수_10  승하차총승객수  승하차총승객수합계
# 사용일자     노선명
# 20260501 1호선    10      10      10    10         10       10         10
#          2호선    50      50      50    50         50       50         50
#          3호선    34      34      34    34         34       34         34
#          4호선    26      26      26    26         26       26         26
#          5호선    56      56      56    56         56       56         56
# ...             ..     ...     ...   ...        ...      ...        ...
# 20260531 안산선    13      13      13    13         13       13         13
#          우이신설선  13      13      13    13         13       13         13
#          일산선    11      11      11    11         11       11         11
#          장항선     7       7       7     7          7        7          7
#          중앙선    21      21      21    21         21       21         21
#
# [837 rows x 7 columns]

# %% [markdown]
# ## 9. 결측값(Nan)

# %%
df2['3호선'] = np.nan

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19131 entries, 0 to 19130
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용일자    19131 non-null  int64
#  1   노선명     19131 non-null  object
#  2   역명      19131 non-null  object
#  3   승차총승객수  19131 non-null  int64
#  4   하차총승객수  19131 non-null  int64
#  5   등록일자    19131 non-null  int64
#  6   3호선     0 non-null      float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 1.0+ MB

# %%
df2.isna().sum()
df2.isnull().sum()
# Out:
# 사용일자          0
# 노선명           0
# 역명            0
# 승차총승객수        0
# 하차총승객수        0
# 등록일자          0
# 3호선       19131
# dtype: int64

# %%
# 타이타닉 데이터셋 로드
td = pd.read_csv('data/titanic/train.csv')

# %%
td.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
td.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
td.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 결측치 대체
td['Age'] = td['Age'].fillna(td['Age'].mean())

# %%
td.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
td.drop(columns = 'Cabin', inplace = True)

# %%
td.isnull().sum()

# %%
# Nan 값을 이전 값으로 대체
td['Embarked'] = td['Embarked'].ffill()

# %%
td.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64
