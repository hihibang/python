# %% [markdown]
# # DataFrame sort agg groupby

# %%
import warnings
warnings.filterwarnings(action='ignore')

import pandas as pd
import numpy as np

# %%
titanic_df = pd.read_csv('data/titanic/train.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## 1. DataFrame 정렬(sort)
#
# ### (1) sort_values()
# - DataFrame을 특정 컬럼 기준으로 정렬할 때 사용
# - 문법
#
#   DF.sort_values(by='컬럼', ascending=True)
#   - ascending=T 오름차순
#   - ascending=F 내림차순

# %%
td_sort_name = titanic_df.sort_values(by= 'Name')
td_sort_name.reset_index(inplace=True)
td_sort_name.drop(columns='index', axis=1, inplace=True)
td_sort_name.head()
# Out:
#    PassengerId  Survived  Pclass                                   Name  \
# 0          846         0       3                    Abbing, Mr. Anthony
# 1          747         0       3            Abbott, Mr. Rossmore Edward
# 2          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 3          309         0       2                    Abelson, Mr. Samuel
# 4          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
#
#       Sex   Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 0    male  42.0      0      0  C.A. 5547   7.55   NaN        S
# 1    male  16.0      1      1  C.A. 2673  20.25   NaN        S
# 2  female  35.0      1      1  C.A. 2673  20.25   NaN        S
# 3    male  30.0      1      0  P/PP 3381  24.00   NaN        C
# 4  female  28.0      1      0  P/PP 3381  24.00   NaN        C

# %%
td_sort_pclass = titanic_df.sort_values(by='Pclass', ascending=False)
td_sort_pclass.reset_index(drop=True, inplace=True) # drop=True 기존 인덱스는 삭제
td_sort_pclass.head()
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 1          512         0       3               Webber, Mr. James    male
# 2          501         0       3                Calic, Mr. Petar    male
# 3          502         0       3             Canavan, Miss. Mary  female
# 4          503         0       3  O'Sullivan, Miss. Bridget Mary  female
#
#     Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171  7.2500   NaN        S
# 1   NaN      0      0  SOTON/OQ 3101316  8.0500   NaN        S
# 2  17.0      0      0            315086  8.6625   NaN        S
# 3  21.0      0      0            364846  7.7500   NaN        Q
# 4   NaN      0      0            330909  7.6292   NaN        Q

# %%
titanic_df.sort_values(by=['Name', 'Pclass']).head(3)
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 845          846         0       3               Abbing, Mr. Anthony    male
# 746          747         0       3       Abbott, Mr. Rossmore Edward    male
# 279          280         1       3  Abbott, Mrs. Stanton (Rosa Hunt)  female
#
#       Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 845  42.0      0      0  C.A. 5547   7.55   NaN        S
# 746  16.0      1      1  C.A. 2673  20.25   NaN        S
# 279  35.0      1      1  C.A. 2673  20.25   NaN        S

# %% [markdown]
# ## 2. 집계 함수(Aggregation)
#
# ### (1) count()
# - 결측치 제외
# - 실제 데이터 갯수 반환

# %%
titanic_df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %% [markdown]
# ### (2) shape
# - 전체 데이터 수를 확인하는 작업에서는 count() 함수보다 shape을 사용하는 것이 유리

# %%
titanic_df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### (3) mean()
# - 평균

# %%
titanic_df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
print(titanic_df['Fare'].mean().round())
# Out:
# 32.0
